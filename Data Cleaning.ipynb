# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18464\2151744951.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df =pd.read_csv('Dirty Data.csv')
df.head()
# Out:
#   Bio data with information on name, Email, age, City of Birth, and Gender
# 0  ruqayyah salihu-ibrahimEmailruqayyahsalihu@@gm...
# 1  isere clementEmailisere@@gmail.com29;#YearsIwo...
# 2  mosunmola adenijiEmailmosunmola@@gmail.com17;#...
# 3  olumuyiwa oyebamijiEmailolumuyiwa@@gmail.com17...
# 4  ibrahim rahmanEmailibrahim@@gmail.com28;#Years...

# %%
df.rename(columns = {'Bio data with information on name, Email, age, City of Birth, and Gender': 'unname'},inplace =True)
df.head()
# Out:
#                                               unname
# 0  ruqayyah salihu-ibrahimEmailruqayyahsalihu@@gm...
# 1  isere clementEmailisere@@gmail.com29;#YearsIwo...
# 2  mosunmola adenijiEmailmosunmola@@gmail.com17;#...
# 3  olumuyiwa oyebamijiEmailolumuyiwa@@gmail.com17...
# 4  ibrahim rahmanEmailibrahim@@gmail.com28;#Years...

# %%
df['Name']= df['unname'].apply(lambda x: x.split('Email',1)[0] if 'Email' in x else x)
df
# Out:
#                                                unname  \
# 0   ruqayyah salihu-ibrahimEmailruqayyahsalihu@@gm...
# 1   isere clementEmailisere@@gmail.com29;#YearsIwo...
# 2   mosunmola adenijiEmailmosunmola@@gmail.com17;#...
# 3   olumuyiwa oyebamijiEmailolumuyiwa@@gmail.com17...
# 4   ibrahim rahmanEmailibrahim@@gmail.com28;#Years...
# 5   ibrahim alarapeEmailibrahim@@gmail.com30;#Year...
# 6   kolawole nayinmotEmailkolawole@@gmail.com26;#Y...
# 7   temitope agudaEmailtemitope@@gmail.com23;#Year...
# 8   oladepo kehinde abdulsemiuEmailoladepokehinde@...
# 9   tijani muhydeenEmailtijaniokuwafemi@@gmail.com...
# 10  adebayo abdulrahmanEmailadebayoabdulrahman@@gm...
# 11  abdulwahab mustaphaEmailabdulwahab@@gmail.com2...
# 12  adisa muritalaEmailadisa@@gmail.com29;#YearsIf...
# 13  atitebi zaynabEmailatitebizaynab@@gmail.com28;...
# 14  hassana abdulkadirEmailhassana@@gmail.com16;#Y...
# 15  asmau nurainEmailasmau@@gmail.com27;#YearsMush...
# ...

# %%
df['email'] =df['unname'].apply(lambda x: x.split('Email',1)[1].split('@@',1)[0] 
             + '@' + x.split('@@',1)[1].split(';',1)[0] if 'Email' in x else x)
df.head()
# Out:
#                                               unname                     Name  \
# 0  ruqayyah salihu-ibrahimEmailruqayyahsalihu@@gm...  ruqayyah salihu-ibrahim
# 1  isere clementEmailisere@@gmail.com29;#YearsIwo...            isere clement
# 2  mosunmola adenijiEmailmosunmola@@gmail.com17;#...        mosunmola adeniji
# 3  olumuyiwa oyebamijiEmailolumuyiwa@@gmail.com17...      olumuyiwa oyebamiji
# 4  ibrahim rahmanEmailibrahim@@gmail.com28;#Years...           ibrahim rahman
#
#                         email
# 0  ruqayyahsalihu@gmail.com21
# 1           isere@gmail.com29
# 2       mosunmola@gmail.com17
# 3       olumuyiwa@gmail.com17
# 4         ibrahim@gmail.com28

# %%
df['Email']=df['email'].str.extract(r'([^\d]+)\d+')
df.head()
# Out:
#                                               unname                     Name  \
# 0  ruqayyah salihu-ibrahimEmailruqayyahsalihu@@gm...  ruqayyah salihu-ibrahim
# 1  isere clementEmailisere@@gmail.com29;#YearsIwo...            isere clement
# 2  mosunmola adenijiEmailmosunmola@@gmail.com17;#...        mosunmola adeniji
# 3  olumuyiwa oyebamijiEmailolumuyiwa@@gmail.com17...      olumuyiwa oyebamiji
# 4  ibrahim rahmanEmailibrahim@@gmail.com28;#Years...           ibrahim rahman
#
#                         email                     Email
# 0  ruqayyahsalihu@gmail.com21  ruqayyahsalihu@gmail.com
# 1           isere@gmail.com29           isere@gmail.com
# 2       mosunmola@gmail.com17       mosunmola@gmail.com
# 3       olumuyiwa@gmail.com17       olumuyiwa@gmail.com
# 4         ibrahim@gmail.com28         ibrahim@gmail.com

# %%
df['Age'] = df['email'].apply(lambda x: x.split('.com',1)[1])
df.head()
# Out:
#                                               unname                     Name  \
# 0  ruqayyah salihu-ibrahimEmailruqayyahsalihu@@gm...  ruqayyah salihu-ibrahim
# 1  isere clementEmailisere@@gmail.com29;#YearsIwo...            isere clement
# 2  mosunmola adenijiEmailmosunmola@@gmail.com17;#...        mosunmola adeniji
# 3  olumuyiwa oyebamijiEmailolumuyiwa@@gmail.com17...      olumuyiwa oyebamiji
# 4  ibrahim rahmanEmailibrahim@@gmail.com28;#Years...           ibrahim rahman
#
#                         email                     Email Age
# 0  ruqayyahsalihu@gmail.com21  ruqayyahsalihu@gmail.com  21
# 1           isere@gmail.com29           isere@gmail.com  29
# 2       mosunmola@gmail.com17       mosunmola@gmail.com  17
# 3       olumuyiwa@gmail.com17       olumuyiwa@gmail.com  17
# 4         ibrahim@gmail.com28         ibrahim@gmail.com  28

# %%
df['code'] = df['unname'].apply(lambda x:x.split('Years',1)[1])
df['Name']=df['Name'].str.replace('-' ,' ')	
df.head()
# Out:
#                                               unname                     Name  \
# 0  ruqayyah salihu-ibrahimEmailruqayyahsalihu@@gm...  ruqayyah salihu ibrahim
# 1  isere clementEmailisere@@gmail.com29;#YearsIwo...            isere clement
# 2  mosunmola adenijiEmailmosunmola@@gmail.com17;#...        mosunmola adeniji
# 3  olumuyiwa oyebamijiEmailolumuyiwa@@gmail.com17...      olumuyiwa oyebamiji
# 4  ibrahim rahmanEmailibrahim@@gmail.com28;#Years...           ibrahim rahman
#
#                         email                     Email Age               code
# 0  ruqayyahsalihu@gmail.com21  ruqayyahsalihu@gmail.com  21     Ife GenderMale
# 1           isere@gmail.com29           isere@gmail.com  29     Iwo GenderMale
# 2       mosunmola@gmail.com17       mosunmola@gmail.com  17   Ila GenderFemale
# 3       olumuyiwa@gmail.com17       olumuyiwa@gmail.com  17  Ibadan GenderMale
# 4         ibrahim@gmail.com28         ibrahim@gmail.com  28   Ikeja GenderMale

# %%
df['City of Birth']=df['code'].apply(lambda x:x.split('Gender',1)[0])
df['Gender']=df['code'].apply(lambda x:x.split('Gender',1)[1])
data =df[['Name','Email','Age','City of Birth','Gender']]
data
# Out:
#                           Name                         Email Age  \
# 0      ruqayyah salihu ibrahim      ruqayyahsalihu@gmail.com  21
# 1                isere clement               isere@gmail.com  29
# 2            mosunmola adeniji           mosunmola@gmail.com  17
# 3          olumuyiwa oyebamiji           olumuyiwa@gmail.com  17
# 4               ibrahim rahman             ibrahim@gmail.com  28
# 5              ibrahim alarape             ibrahim@gmail.com  30
# 6            kolawole nayinmot            kolawole@gmail.com  26
# 7               temitope aguda            temitope@gmail.com  23
# 8   oladepo kehinde abdulsemiu      oladepokehinde@gmail.com  15
# 9              tijani muhydeen     tijaniokuwafemi@gmail.com  20
# 10         adebayo abdulrahman  adebayoabdulrahman@gmail.com  24
# 11         abdulwahab mustapha          abdulwahab@gmail.com  20
# 12              adisa muritala               adisa@gmail.com  29
# ...

# %%
data.head()
# Out:
#                       Name                     Email Age City of Birth  Gender
# 0  ruqayyah salihu ibrahim  ruqayyahsalihu@gmail.com  21          Ife     Male
# 1            isere clement           isere@gmail.com  29          Iwo     Male
# 2        mosunmola adeniji       mosunmola@gmail.com  17          Ila   Female
# 3      olumuyiwa oyebamiji       olumuyiwa@gmail.com  17       Ibadan     Male
# 4           ibrahim rahman         ibrahim@gmail.com  28        Ikeja     Male

# %%
 g1 = data['Gender'].value_counts().sort_index()
g1
# Out:
# Gender
# Female     9
# Male      12
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,4))
g1.plot(kind = 'bar',color =('#768E36','#52A6F7'))
plt.xlabel('subject',fontsize= 15,color ='black')
plt.ylabel('counts',fontsize =15,color ='black')
plt.title('Total male and female', fontweight= 'bold')
plt.grid(axis='y',linestyle ='-',alpha= 0.3,color = '#0F0F0F')
plt.xticks(rotation=45)
plt.show()

# %%
g3 =data[data['Age'].astype(int)> 20]
g3
# Out:
#                          Name                         Email Age City of Birth  \
# 0     ruqayyah salihu ibrahim      ruqayyahsalihu@gmail.com  21          Ife
# 1               isere clement               isere@gmail.com  29          Iwo
# 4              ibrahim rahman             ibrahim@gmail.com  28        Ikeja
# 5             ibrahim alarape             ibrahim@gmail.com  30      Ikorodu
# 6           kolawole nayinmot            kolawole@gmail.com  26         Ketu
# 7              temitope aguda            temitope@gmail.com  23       Somolu
# 10        adebayo abdulrahman  adebayoabdulrahman@gmail.com  24        Ikire
# 12             adisa muritala               adisa@gmail.com  29     Ifelodun
# 13             atitebi zaynab       atitebizaynab@gmail.com  28      Jalingo
# 15               asmau nurain               asmau@gmail.com  27       Mushin
# 16             afolabi saheed             afolabi@gmail.com  21       Owerri
# ...

# %%
g2 =g3['Gender'].value_counts()
g2
# Out:
# Gender
# Male      8
# Female    6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,4))
g2.plot(kind='pie',color=('#5FD8D4','#E45F8E'), autopct=lambda x: f'{x:.1f}% ({int(x*sum(g2)/100)})')
plt.title('Male and Female above 20')
plt.ylabel('')
plt.show()
